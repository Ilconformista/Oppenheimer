# %% [markdown]
# <a href="https://colab.research.google.com/github/Ilconformista/Oppenheimer/blob/main/testing_sequencing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio
# !pip install gdown
# !pip install gtts
# !pip install Pillow



import gradio as gr
from PIL import Image
import base64
from io import BytesIO
from gtts import gTTS
import gdown

# Define the URLs of the images
image_urls = [
    "https://drive.google.com/uc?id=19zhvDXwloycllKv0q8fN4AkNWJ3WC74I",
    "https://drive.google.com/uc?id=1_9MzEhc_YfwYFGVLUUlFW3YpSuZk6FSV",
    "https://drive.google.com/uc?id=1v1JRBsza_pnpLGv_vgORpeYDo9DLmMAD",
    "https://drive.google.com/uc?id=1aunq6D-MuES5BKkkxPFYH4R5h6W6WlDE"
]

# Define the local file names
image_files = [
    "image1.png",
    "image2.png",
    "image3.png",
    "image4.png"
]

# Download the images
for url, file in zip(image_urls, image_files):
    gdown.download(url, file, quiet=False)

# Descriptions for each scene
descriptions = [
    "Alex, Mia, and Sam eagerly plan their treasure hunt in a room filled with maps and exploration tools.",
    "The friends hike through a dense forest, guided by their ancient map.",
    "Deep in Whispering Hollow, they discover an ancient chest filled with historical artifacts.",
    "The village celebrates as Alex, Mia, and Sam present their find to the local museum."
]

# Generate audio files for each description
audio_files = []
for i, desc in enumerate(descriptions):
    tts = gTTS(desc)
    audio_file = f"audio_{i+1}.mp3"
    tts.save(audio_file)
    audio_files.append(audio_file)

# Load images
images = [
    Image.open("image1.png"),
    Image.open("image2.png"),
    Image.open("image3.png"),
    Image.open("image4.png")
]

# Assign labels to images
labels = ['B', 'D', 'A', 'C']
label_image_description_audio = list(zip(labels, images, descriptions, audio_files))

# Ensure the display order is A -> B -> C -> D
display_order = ['A', 'B', 'C', 'D']
label_image_description_audio_sorted = sorted(label_image_description_audio, key=lambda x: display_order.index(x[0]))

# Function to check the order
def check_order(a, b, c, d):
    user_order = [a.upper(), b.upper(), c.upper(), d.upper()]
    correct_order = ['B', 'D', 'A', 'C']
    return "Correct!" if user_order == correct_order else "Try again."

# Helper function to convert image to base64 string
def img_to_base64(img):
    buffered = BytesIO()
    img.save(buffered, format="PNG")
    img_str = base64.b64encode(buffered.getvalue()).decode()
    return img_str

# Create Gradio interface using gr.Blocks for layout control
with gr.Blocks(css=".small-audio { height: 180px !important; width: 230px !important; }") as iface:
    gr.Markdown("The images are displayed below with labels A, B, C, and D. Enter the correct sequence according to the story.")
    with gr.Row():
        for label, img, desc, audio in label_image_description_audio_sorted:
            with gr.Column():
                gr.Image(value=img, label=label, width=300)  # Display image with label
                gr.Markdown(f"**{label}**: {desc}")  # Display description below the image
                gr.Audio(value=audio, elem_classes="small-audio")  # Display TTS audio below the description with smaller size
    with gr.Row():
        a = gr.Textbox(label="Enter label for the first part of story")
        b = gr.Textbox(label="Enter label for the second part of story")
        c = gr.Textbox(label="Enter label for the third part of story")
        d = gr.Textbox(label="Enter label for the fourth part of story")
    btn = gr.Button("Check Order")
    output = gr.Textbox(label="Result")

    btn.click(fn=check_order, inputs=[a, b, c, d], outputs=output)

iface.launch()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 MB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.1/320.1 kB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 76.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 10.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ...
# ---------------------------------------------------------------------------
# FileURLRetrievalError                     Traceback (most recent call last)
# ...

# %%
# !pip install gradio
# !pip install gdown
# !pip install gtts
# !pip install Pillow

import gradio as gr
# from PIL import Image  # No longer needed
import base64
from io import BytesIO
from gtts import gTTS
import gdown

# Define the URLs of the videos
video_urls = [
    "https://drive.google.com/file/d/1fBG514BLCvr78iuRSnFKr362SItZH3nz/view?usp=drive_link",  # Replace with your Google Drive video link
    "https://drive.google.com/file/d/1KSN0a_FPIZYf1yhZkcFgBN6J8GTfNsor/view?usp=drive_link",  # Replace with your Google Drive video link
    "https://drive.google.com/file/d/1vvdkTo_xrwHfqEDtBzh6RzgRYVaqNRyl/view?usp=drive_link",  # Replace with your Google Drive video link
    "https://drive.google.com/file/d/1Yr9mhCVCUgVGFCsphnhVBnOQtZWN7zHQ/view?usp=drive_link"   # Replace with your Google Drive video link
]

# Define the local file names
video_files = [
    "video1.mp4",
    "video2.mp4",
    "video3.mp4",
    "video4.mp4"
]

# Download the videos
for url, file in zip(video_urls, video_files):
    gdown.download(url, file, quiet=False)

# Descriptions for each scene (keep as is)
descriptions = [
    "Alex, Mia, and Sam eagerly plan their treasure hunt in a room filled with maps and exploration tools.",
    "The friends hike through a dense forest, guided by their ancient map.",
    "Deep in Whispering Hollow, they discover an ancient chest filled with historical artifacts.",
    "The village celebrates as Alex, Mia, and Sam present their find to the local museum."
]

# Generate audio files for each description (keep as is)
audio_files = []
for i, desc in enumerate(descriptions):
    tts = gTTS(desc)
    audio_file = f"audio_{i+1}.mp3"
    tts.save(audio_file)
    audio_files.append(audio_file)


# Assign labels to videos
labels = ['B', 'D', 'A', 'C']
label_video_description_audio = list(zip(labels, video_files, descriptions, audio_files))

# Ensure the display order is A -> B -> C -> D
display_order = ['A', 'B', 'C', 'D']
label_video_description_audio_sorted = sorted(label_video_description_audio, key=lambda x: display_order.index(x[0]))

# Function to check the order (keep as is)
def check_order(a, b, c, d):
    user_order = [a.upper(), b.upper(), c.upper(), d.upper()]
    correct_order = ['B', 'D', 'A', 'C']
    return "Correct!" if user_order == correct_order else "Try again."

# Create Gradio interface using gr.Blocks for layout control
with gr.Blocks(css=".small-audio { height: 180px !important; width: 230px !important; }") as iface:
    gr.Markdown("The videos are displayed below with labels A, B, C, and D. Enter the correct sequence according to the story.")
    with gr.Row():
        for label, video_file, desc, audio in label_video_description_audio_sorted:
            with gr.Column():
                gr.Video(value=video_file, label=label, width=300)  # Display video with label
                gr.Markdown(f"**{label}**: {desc}")  # Display description below the video
                gr.Audio(value=audio, elem_classes="small
# Out:
#   File "<ipython-input-3-9a14211ff053>", line 72
#     gr.Audio(value=audio, elem_classes="small
#                                        ^
# SyntaxError: unterminated string literal (detected at line 72)

# %%
# !pip install gradio
# !pip install gdown
# !pip install gtts
# !pip install Pillow

import gradio as gr
from gtts import gTTS
import gdown

# Define the URLs of the videos
video_urls = [
    "https://drive.google.com/uc?id=1fBG514BLCvr78iuRSnFKr362SItZH3nz",  # Replace with your Google Drive video link
    "https://drive.google.com/uc?id=1KSN0a_FPIZYf1yhZkcFgBN6J8GTfNsor",  # Replace with your Google Drive video link
    "https://drive.google.com/uc?id=1vvdkTo_xrwHfqEDtBzh6RzgRYVaqNRyl",  # Replace with your Google Drive video link
    "https://drive.google.com/uc?id=1Yr9mhCVCUgVGFCsphnhVBnOQtZWN7zHQ"   # Replace with your Google Drive video link
]

# Define the local file names
video_files = [
    "video1.mp4",
    "video2.mp4",
    "video3.mp4",
    "video4.mp4"
]

# Download the videos
for url, file in zip(video_urls, video_files):
    gdown.download(url, file, quiet=False)

# Descriptions for each scene
descriptions = [
    "Truman praises Oppenheimer for his role in ending the war and saving American lives, referencing Hiroshima. Oppenheimer, visibly burdened, emphasizes both Hiroshima and Nagasaki, downplaying his personal contribution to the invention..",
    "Oppenheimer shares Teller's calculations with Einstein, explaining how a nuclear chain reaction could become uncontrollable, leading to catastrophic consequences. Einstein, after studying the data, warns that it could ignite the atmosphere, potentially destroying the Earth..",
    "Rabi worries about using science to create a powerful weapon that harms everyone, both good and bad. Oppenheimer agrees it's a tough decision but says they must act to stop the Nazis, and Rabi suggests making Hans Bethe the leader of the Theoretical Division..",
    "Groves and Oppenheimer discuss the immense stakes of the atomic bomb project, with Groves noting the pressure to succeed. Oppenheimer reflects on the earlier fear that a nuclear chain reaction could ignite the atmosphere, while Groves confronts the lingering possibility of global destruction.."
]

# Generate audio files for each description
audio_files = []
for i, desc in enumerate(descriptions):
    tts = gTTS(desc)
    audio_file = f"audio_{i+1}.mp3"
    tts.save(audio_file)
    audio_files.append(audio_file)

# Assign labels to videos
labels = ['B', 'D', 'A', 'C']
label_video_description_audio = list(zip(labels, video_files, descriptions, audio_files))

# Ensure the display order is A -> B -> C -> D
display_order = ['A', 'B', 'C', 'D']
label_video_description_audio_sorted = sorted(label_video_description_audio, key=lambda x: display_order.index(x[0]))

# Function to check the order
def check_order(a, b, c, d):
    user_order = [a.upper(), b.upper(), c.upper(), d.upper()]
    correct_order = ['B', 'D', 'A', 'C']
    return "Correct!" if user_order == correct_order else "Try again."

# Create Gradio interface using gr.Blocks for layout control
with gr.Blocks(css=".small-audio { height: 180px !important; width: 230px !important; }") as iface:
    gr.Markdown("### The videos are displayed below with labels A, B, C, and D. Enter the correct sequence according to the story.")
    with gr.Row():
        for label, video_file, desc, audio in label_video_description_audio_sorted:
            with gr.Column():
                gr.Video(value=video_file, label=label, width=300)  # Display video with label
                gr.Markdown(f"**{label}**: {desc}")  # Display description below the video
                gr.Audio(value=audio, elem_classes="small-audio")  # Display corresponding audio below the description

    # Input fields for the user to enter their guessed order
    with gr.Row():
        input_a = gr.Textbox(label="1st video label")
        input_b = gr.Textbox(label="2nd video label")
        input_c = gr.Textbox(label="3rd video label")
        input_d = gr.Textbox(label="4th video label")

    # Button to submit the order and output the result
    with gr.Row():
        submit_button = gr.Button("Submit")
        result = gr.Textbox(label="Result", interactive=False)

    # Set the function to be called when the button is clicked
    submit_button.click(check_order, inputs=[input_a, input_b, input_c, input_d], outputs=result)

# Launch the Gradio interface
iface.launch()
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1fBG514BLCvr78iuRSnFKr362SItZH3nz
# To: /content/video1.mp4
# 100%|██████████| 4.94M/4.94M [00:00<00:00, 29.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1KSN0a_FPIZYf1yhZkcFgBN6J8GTfNsor
# To: /content/video2.mp4
# 100%|██████████| 21.6M/21.6M [00:00<00:00, 67.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1vvdkTo_xrwHfqEDtBzh6RzgRYVaqNRyl
# To: /content/video3.mp4
# 100%|██████████| 6.65M/6.65M [00:00<00:00, 24.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Yr9mhCVCUgVGFCsphnhVBnOQtZWN7zHQ
# To: /content/video4.mp4
# 100%|██████████| 4.80M/4.80M [00:00<00:00, 26.4MB/s]
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# ...
